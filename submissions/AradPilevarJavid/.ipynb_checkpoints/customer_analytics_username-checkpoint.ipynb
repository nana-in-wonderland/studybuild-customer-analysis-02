# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
import sys
if (sys.executable) == '/home/arad/Desktop/StudyBuild/studybuild-customer-analysis-02/submissions/AradPilevarJavid/venv/bin/python':    print("Success")
# Out:
# Success

# %%
df = pd.read_excel("cleaned_dataset_1.xlsx")

# %% [markdown]
# ### I would first paste the data cleaning from the pdf

# %%
kpi_summary = pd.Series({
"Unique customers": df["customer_id"].nunique(),
"Total customer spending": df["total_spending"].sum(),
"Average spending per customer": df["total_spending"].mean(),
"Average purchase count": df["purchase_count"].mean(),
"Average satisfaction": df["satisfaction_score"].mean(),
"Total returned items": df["returned_items"].sum()
}, name="Value")
display(kpi_summary)
# Out:
# Unique customers                     60.000000
# Total customer spending          201985.730000
# Average spending per customer      3366.428833
# Average purchase count               17.650000
# Average satisfaction                  2.983333
# Total returned items                244.000000
# Name: Value, dtype: float64

# %% [markdown]
# ### Chart 1: Top 10 cities

# %%
chart1 = city_summary.nlargest(10, "total_revenue").sort_values("total_revenue")
chart1_labels = chart1["province"] + " - " + chart1["city"]
plt.figure(figsize=(10, 6))
plt.barh(chart1_labels, chart1["total_revenue"])
plt.title("Top 10 Cities by Total Customer Spending")
plt.xlabel("Total customer spending")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 2: Valuable customers at risk

# %%
plt.figure(figsize=(10, 6))
plt.scatter(
risk_df.loc[~risk_df["at_risk"], "last_purchase_days"],
risk_df.loc[~risk_df["at_risk"], "total_spending"],
alpha=0.4,
label="Other customers"
)
plt.scatter(
risk_df.loc[risk_df["at_risk"], "last_purchase_days"],
risk_df.loc[risk_df["at_risk"], "total_spending"],
marker="X",
s=110,
label="At risk"
)
plt.title("Valuable Customers at Risk of Becoming Inactive")
plt.xlabel("Days since last purchase")
plt.ylabel("Total spending")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 3: Discount comparison

# %%
summary_by_discount.plot(
x="discount_used",
y=["avg_total_spending", "avg_returned_items"],
kind="bar",
figsize=(9, 5)
)
plt.title("Customer Value and Returns by Discount Use")
plt.xlabel("Discount used")
plt.ylabel("Average")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 summary_by_discount.plot(
#       2 x="discount_used",
#       3 y=["avg_total_spending", "avg_returned_items"],
#       4 kind="bar",
#
# NameError: name 'summary_by_discount' is not defined

# %% [markdown]
# ### Export core result tables

# %%
with pd.ExcelWriter("customer_analytics_results.xlsx") as writer:
kpi_summary.to_excel(writer, sheet_name="KPI")
city_summary.to_excel(writer, sheet_name="City Analysis", index=False)
top_loyal_customers.to_excel(writer, sheet_name="Top Loyal Customers", index=False)
at_risk_customers.to_excel(writer, sheet_name="At Risk Customers", index=False)
summary_by_discount.to_excel(writer, sheet_name="Discount Analysis", index=False)
print("customer_analytics_results.xlsx has been saved.")
